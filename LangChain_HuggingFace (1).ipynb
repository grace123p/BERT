# %%
# !pip -q install langchain huggingface_hub transformers sentence_transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 55.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 81.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 99.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 72.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 6.0 MB/s eta 0:00:00
# ...

# %%
pip install pypdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.8/254.8 kB 18.4 MB/s eta 0:00:00
# ...

# %%
import os


os.environ['HUGGINGFACEHUB_API_TOKEN'] = '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'

# %%
from langchain.document_loaders import DirectoryLoader

import os
import nltk

# %%
from langchain.document_loaders import  PyPDFLoader

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
loader = PyPDFLoader("chessFundamentals.pdf")

# %%
from langchain.embeddings import HuggingFaceEmbeddings

# %%
data=loader.load()

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=600, chunk_overlap=50)

# %%
texts = text_splitter.split_documents(data)

# %%
print(texts[1])
# Out:
# page_content='BYJOSE R.CAPABLANCA\nAPRIMER OFCHESS' metadata={'source': 'chessFundamentals.pdf', 'page': 5}

# %%
embeddings = HuggingFaceEmbeddings()

# %%
from langchain.vectorstores import FAISS

# %%
pip install faiss-cpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 74.3 MB/s eta 0:00:00
# ...

# %%
# Get your docsearch ready
docsearch = FAISS.from_documents(texts, embeddings)

# %%
from langchain.llms import HuggingFaceHub

# %%
llm=HuggingFaceHub(repo_id="google/flan-t5-xxl", model_kwargs={"temperature":0.2,"max_length":512})

# %%
from langchain.chains import RetrievalQA

# %%
qa = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=docsearch.as_retriever())

# %%
query = "Is it a draw if the opposing King is in front of the pawn?"
qa.run(query)
# Out:
# 'yes'

# %%
"""from langchain import PromptTemplate, HuggingFaceHub, LLMChain

template = """"""Question: {question}

Answer: Let's think step by step."""
"""
prompt = PromptTemplate(template=template, input_variables=["question"])
"""

# %%
"""
llm_chain = LLMChain(prompt=prompt,
                     llm=HuggingFaceHub(repo_id="google/flan-t5-xxl",
                                        model_kwargs={"temperature":0.2,
                                                      "max_length":64}))

# %%
"""
question = "What is the capital of India?"

print(llm_chain.run(question))
# Out:
# Delhi is the capital of India. Delhi is the capital of India. The answer: Delhi.
